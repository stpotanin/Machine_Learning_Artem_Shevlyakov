# %% [markdown]
# ## Задача 10.4.1
# https://stepik.org/lesson/83974/step/1
#
# Комитет состоит из трех классификаторов. Окончательное решение принимается по большинству голосов. Классификаторы имеют точность 0,8 0,9 1 соответственно.
#
# Заполните пропуски
#
# Точность ансамбля алгоритмов равна `____` (ответ округлить до двух знаков после запятой).

# %%
1 - ((1-0.8)*(1-0.9)*(1) + 0 + 0)
# Out:
# [1] 0.98

# %% [markdown]
# ## Задача 10.4.2
# https://stepik.org/lesson/83974/step/2
#
# Для классификации используется схема взвешенного голосования. Допустим, что объект `А` был определен первым и третьим классификаторами как объект из класса `1`, а второй классификатор определил `А` как объект класса `-1`. Результат взвешенного голосования, если веса при классификаторах равны `2`, `4`, `3` соответственно, отнесет объект `A` к классу `____`

# %%
1
# Out:
# [1] 1

# %% [markdown]
# ## Задача 10.4.3
# https://stepik.org/lesson/83974/step/3
#
# Вспомните работу алгоритма Random Forest (случайный лес). К какому типу ансамбля он относится:
#
# *   взвешенное голосование
# *   `голосование по большинству (комитет)`
# *   градиентный бустинг

# %% [markdown]
# ## Задача 10.4.4
# https://stepik.org/lesson/83974/step/4
#
# Если к модели линейной регрессии применить процедуру бустинга, причем на втором этапе будет также строится линейная модель, то точность предсказания:
#
# **Выберите один вариант из списка**
#
# *   уменьшится
# *   возрастет
# *   `останется прежней`

# %% [markdown]
# ## Задача 10.4.5
# https://stepik.org/lesson/83974/step/5
#
# Была построена модель регрессии, предсказывающая целевой признак `Y`, и предсказанные значения признаков `Y'` указаны в таблице.
#
# <img src=https://ucarecdn.com/d90dc039-6e6c-4788-bfda-7a2d8e5ec689/>
#
# Будем улучшать качество регрессии с помощью процедуры градиентного бустинга. Тогда следующая модель регрессии будет строиться с помощью нового столбца, состоящего из чисел:
#
# **Выберите один вариант из списка**
#
# *    2 2
# *    `-1 2`
# *    -2 -2
# *    1 2
# *    -1 -1
# *    1 1
